# %%
import pyxdf
data,_ = pyxdf.load_xdf('sub.xdf')

# %%
video_stream = next((s for s in data if s['info']['name'][0] == 'cam2'), None)

# %%
video_stream['time_stamps']
# Out:
# array([93713.10144868, 93713.13179892, 93713.16383016, 93713.195832  ,
#        93713.22780354, 93713.25983797, 93713.29180571, 93713.32379935,
#        93713.35581539, 93713.38779063, 93713.41983627, 93713.46782552,
#        93713.49976766, 93713.5315104 , 93713.56374434, 93713.59575948,
#        93713.62775832, 93713.65996855, 93713.69188589, 93713.72402013,
#        93713.75597127, 93713.78828551, 93713.82008905, 93713.868099  ,
#        93713.90061264, 93713.93335878, 93713.96378942, 93713.99624636,
#        93714.0281327 , 93714.06015003, 93714.09417798, 93714.12441331,
#        93714.15613345, 93714.18832509, 93714.21987393, 93714.26827948,
#        93714.30177752, 93714.33222466, 93714.3639405 , 93714.39591384,
#        93714.42899118, 93714.45985841, 93714.49237315, 93714.52410159,
#        93714.55575333, 93714.58804857, 93714.61992961, 93714.66809976,
#        93714.7003671 , 93714.73220404, 93714.76405928, 93714.79620382,
# ...

# %%
data
# Out:
# [{'info': defaultdict(list,
#               {'name': ['cam2'],
#                'type': ['Markers'],
#                'channel_count': ['1'],
#                'nominal_srate': ['0'],
#                'channel_format': ['string'],
#                'source_id': ['15-4-2025 11:39:30'],
#                'version': ['1.1000000000000001'],
#                'created_at': ['93687.065073899998'],
#                'uid': ['784034b9-f75d-4dd8-bab7-b5871beac605'],
#                'session_id': ['default'],
#                'hostname': ['WKS047110'],
#                'v4address': [None],
#                'v4data_port': ['16572'],
#                'v4service_port': ['16572'],
#                'v6address': [None],
#                'v6data_port': ['16572'],
#                'v6service_port': ['16572'],
#                'desc': [None],
#                'stream_id': 1,
#                'effective_srate': 0}),
#   'footer': {'info': defaultdict(list,
# ...
